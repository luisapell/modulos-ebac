# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %matplotlib inline

# Carregar a base de dados
data = pd.read_csv("previsao_de_renda.csv")

# Contingency table para posse de imóvel e renda
contingency_imovel = pd.crosstab(data['posse_de_imovel'], data['renda'])

# Contingency table para posse de veículo e renda
contingency_veiculo = pd.crosstab(data['posse_de_veiculo'], data['renda'])

# Teste qui-quadrado para posse de imóvel
chi2_imovel, p_imovel, _, _ = chi2_contingency(contingency_imovel)
print("p-value para posse de imóvel:", p_imovel)

# Teste qui-quadrado para posse de veículo
chi2_veiculo, p_veiculo, _, _ = chi2_contingency(contingency_veiculo)
print("p-value para posse de veículo:", p_veiculo)
# Out:
# p-value para posse de imóvel: 6.249947445305194e-223
# p-value para posse de veículo: 5.921293274031389e-221

# %%
df_pdr = pd.read_csv('previsao_de_renda.csv')
df_pdr.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
sns.pointplot(data=df_pdr, x='posse_de_imovel', y='renda', dodge=True,errorbar=('ci', 90))
plt.title('Renda em relação à posse de imóvel')
plt.xlabel('Posse de Imóvel')
plt.ylabel('Renda')
plt.show()

# %%
sns.pointplot(data=df_pdr, x='posse_de_veiculo', y='renda', dodge=True, errorbar=('ci', 90))
plt.title('Renda em relação à posse de veículo')
plt.xlabel('Posse de veículo')
plt.ylabel('Renda')
plt.show()

# %%
sns.countplot(x="posse_de_veiculo", hue="posse_de_imovel", data=df_pdr)
plt.title('Posse de veículo vs. Posse de imóvel')
plt.xlabel('Posse de Veículo')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# - Parece discriminar renda,sim, ambos os valores de p-value para posse de imóvel e posse de veículo são extremamente baixos, o que indica que há uma associação estatisticamente significativa entre essas variáveis e a renda. Portanto, tanto a posse de imóvel quanto a posse de veículo parecem discriminar a renda de forma estatisticamente significativa. Isso significa que essas variáveis podem ser boas preditoras da renda.
