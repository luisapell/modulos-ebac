# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# Número de questões por assunto
num_questoes = {
    'Matemática': 24,
    'Português': 18,
    'Geografia': 8,
    'Inglês': 8,
    'História': 8,
    'Física': 12,
    'Química': 12
}

# DataFrames contendo a quantidade de acertos por assunto
dfs = [df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui]

# Calculando o percentual de acerto por assunto
for i, df in enumerate(dfs):
    assunto = list(num_questoes.keys())[i]
    df['Percentual_acerto'] = (df['Qt_acertos'] / num_questoes[assunto]) * 100
    print(f"Percentual de acerto em {assunto}:")
    print(df.head())
# Out:
# Percentual de acerto em Matemática:
#    Qt_acertos  Percentual_acerto
# 0           6          25.000000
# 1          19          79.166667
# 2          14          58.333333
# 3          10          41.666667
# 4           7          29.166667
# Percentual de acerto em Português:
#    Qt_acertos  Percentual_acerto
# 0           7          38.888889
# 1          10          55.555556
# 2          16          88.888889
# 3           7          38.888889
# 4           2          11.111111
# Percentual de acerto em Geografia:
#    Qt_acertos  Percentual_acerto
# 0           7               87.5
# 1           0                0.0
# 2           0                0.0
# 3           3               37.5
# 4           2               25.0
# Percentual de acerto em Inglês:
#    Qt_acertos  Percentual_acerto
# 0           3               37.5
# 1           0                0.0
# 2           5               62.5
# 3           4               50.0
# 4           7               87.5
# Percentual de acerto em História:
#    Qt_acertos  Percentual_acerto
# 0           1               12.5
# 1           0                0.0
# 2           7               87.5
# 3           0                0.0
# 4           0                0.0
# Percentual de acerto em Física:
#    Qt_acertos  Percentual_acerto
# 0           8          66.666667
# 1          11          91.666667
# 2           4          33.333333
# 3           0           0.000000
# 4           9          75.000000
# Percentual de acerto em Química:
#    Qt_acertos  Percentual_acerto
# 0           3          25.000000
# 1           8          66.666667
# 2           4          33.333333
# 3           8          66.666667
# 4           3          25.000000

# %%
# Calculando o total de acertos de cada aluno
df_total_acertos = pd.DataFrame()
for df in dfs:
    if df_total_acertos.empty:
        df_total_acertos = df.copy()
    else:
        df_total_acertos += df

# Adicionando uma coluna com o total de acertos de cada aluno
df_total_acertos['Total_acertos'] = df_total_acertos.sum(axis=1)
print("Total de acertos de cada aluno:")
print(df_total_acertos.head())
# Out:
# Total de acertos de cada aluno:
#    Qt_acertos  Percentual_acerto  Total_acertos
# 0          35         293.055556     328.055556
# 1          48         293.055556     341.055556
# 2          50         363.888889     413.888889
# 3          32         234.722222     266.722222
# 4          30         252.777778     282.777778

# %%
# Calculando o percentual geral de cada aluno
total_questoes = sum(num_questoes.values())
df_total_acertos['Percentual_geral'] = (df_total_acertos['Total_acertos'] / total_questoes) * 100
print("Percentual geral de cada aluno:")
print(df_total_acertos.head())
# Out:
# Percentual geral de cada aluno:
#    Qt_acertos  Percentual_acerto  Total_acertos  Percentual_geral
# 0          35         293.055556     328.055556        364.506173
# 1          48         293.055556     341.055556        378.950617
# 2          50         363.888889     413.888889        459.876543
# 3          32         234.722222     266.722222        296.358025
# 4          30         252.777778     282.777778        314.197531

# %%
# Contando o número de alunos com nota maior que 45
num_alunos_aprovados = len(df_total_acertos[df_total_acertos['Total_acertos'] > 45])
print(f"Número de alunos com nota maior que 45: {num_alunos_aprovados}")
# Out:
# Número de alunos com nota maior que 45: 100

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# Verificando alunos desqualificados em Matemática, Física ou Química
df_desqualificados = pd.DataFrame()
for df in [df_mat, df_fis, df_qui]:
    alunos_desqualificados = df[df['Qt_acertos'] == 0]
    df_desqualificados = pd.concat([df_desqualificados, alunos_desqualificados])

# Removendo duplicatas (alunos que zeraram mais de uma matéria)
df_desqualificados = df_desqualificados.drop_duplicates()

# Contando o número de alunos desqualificados
num_alunos_desqualificados = len(df_desqualificados)
print(f"Número de alunos desqualificados: {num_alunos_desqualificados}")

# Calculando a média dos alunos desqualificados em História e Geografia
media_hist_geog = df_desqualificados[['Qt_acertos']].mean()
print(f"Média dos alunos desqualificados em História e Geografia:\n{media_hist_geog}")

# Montando DataFrame com os alunos que passaram para a segunda fase
df_alunos_passaram = df_total_acertos[df_total_acertos['Total_acertos'] > 45]
df_alunos_passaram = df_alunos_passaram.drop(df_desqualificados.index, errors='ignore')

print("Alunos que passaram para a segunda fase:")
print(df_alunos_passaram.head())
# Out:
# Número de alunos desqualificados: 1
# Média dos alunos desqualificados em História e Geografia:
# Qt_acertos    0.0
# dtype: float64
# Alunos que passaram para a segunda fase:
#    Qt_acertos  Percentual_acerto  Total_acertos  Percentual_geral
# 0          35         293.055556     328.055556        364.506173
# 1          48         293.055556     341.055556        378.950617
# 2          50         363.888889     413.888889        459.876543
# 3          32         234.722222     266.722222        296.358025
# 4          30         252.777778     282.777778        314.197531

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'

# %%
# 1) link estava desaturalizado, atualizei
url = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00001-97829158-cc41-4c75-aec4-752344e6e938.c000.csv'
df = pd.read_csv(url, sep=';', decimal= ',')

# Contando o número de registros
num_vacinas = len(df)
print(f"Quantidade de vacinas registradas: {num_vacinas}")
# Out:
# Quantidade de vacinas registradas: 375262

# %%
# 2)Contando o número de pacientes foram vacinados
num_pacientes = df['paciente_id'].nunique()
print(f"Número de pacientes vacinados: {num_pacientes}")
# Out:
# Número de pacientes vacinados: 308567

# %%
# 3) Removendo caracteres especiais do campo 'vacina_descricao_dose'
df['vacina_descricao_dose'] = df['vacina_descricao_dose'].str.replace('\x89Ûª', '', regex=False)

# Filtrando para pegar apenas a primeira dose
primeira_dose = df[df['vacina_descricao_dose'] == '1ª Dose']

# Contando o número de pacientes únicos que tomaram a primeira dose
pacientes_primeira_dose = primeira_dose['paciente_id'].nunique()
print(f"Número de pacientes que tomaram a primeira dose: {pacientes_primeira_dose}")
# Out:
# Número de pacientes que tomaram a primeira dose: 141556

# %%
# 3) Contando o número de pacientes únicos que tomaram a primeira dose usando value_counts()
pacientes_primeira_dose_alt = df[df['vacina_descricao_dose'] == '1ª Dose']['paciente_id'].value_counts().shape[0]
print(f"Número de pacientes que tomaram a primeira dose (alternativa): {pacientes_primeira_dose_alt}")
# Out:
# Número de pacientes que tomaram a primeira dose (alternativa): 141556

# %%
# 4) Filtrando pacientes com menos de 18 anos
menores_18 = df[df['paciente_idade'] < 18]

# Contando o número de pacientes com menos de 18 anos
num_menores_18 = len(menores_18)
print(f"Número de pacientes com menos de 18 anos vacinados: {num_menores_18}")
# Out:
# Número de pacientes com menos de 18 anos vacinados: 70702

# %%
# 5)Contando o número de estabelecimentos únicos
num_estabelecimentos = df['estabelecimento_uf'].nunique()
print(f"Número de estabelecimentos que aplicaram vacina no Acre: {num_estabelecimentos}")
# Out:
# Número de estabelecimentos que aplicaram vacina no Acre: 1

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) Criar uma cópia do DataFrame original contendo somente os registros de vacinas realizadas a menores de 18 anos
df_menores_18 = df[df['paciente_idade'] < 18].copy()
df_menores_18_limitado = df_menores_18.head(20000)
df_menores_18_limitado
# Out:
#                                       document_id  \
# 1       e87ef9d4-15a0-42b6-9247-a347c4fba1f2-i0b0
# 8       8d61afe6-022a-460d-b174-f685973d101c-i0b0
# 15      e970bfe5-4357-4870-b4bd-7b12dab1ccd7-i0b0
# 26      7dda5a6c-62ea-4d78-9ab2-50a9e4a0d6b1-i0b0
# 34      e20987f3-b95e-4fae-9cf3-ad8bbc5e8cea-i0b0
# ...                                           ...
# 104758  c1dc78a1-9718-4050-834e-26b92ec4a0c8-i0b0
# 104765  fe8816ad-c2e5-4113-94b6-82ae715f686b-i0b0
# 104768  f2328f1a-be40-4083-b547-57ffc95e751f-i0b0
# 104772  e8978e71-a05d-44d8-b575-e1e9385a0cb8-i0b0
# 104773  bceaf36e-2faf-44c7-9475-b0e55b4c2c26-i0b0
#
#                                               paciente_id  paciente_idade  \
# 1       47219b9a52a88ad8dd82573557a9be874acc6cb5536c78...             5.0
# 8       5246f3d91ee2c206d92733b2121144ccfc4326c6ac48d2...             5.0
# 15      9b466b4b4385e42d0d4d67a4ce71e02de22ee301b836b2...            13.0
# 26      6a8d9569ea93dcff28097d012706153a56c891016c97bf...            14.0
# 34      de3b437f04ae77b033ec9f8fcc9bb5a660c1ece713f1b4...            15.0
# ...                                                   ...             ...
# 104758  ebf7fb452c27f9c980524f9421a39a41b9f2e368771619...             8.0
# 104765  0a4c2ab94bc72dafaf98d801ddf5698ffb6345e29ea00f...             8.0
# 104768  856a577315cac837efc14d7ef4a7b200c2c3d85f96fc80...            12.0
# 104772  d6613795feb1915d1a0fa03653e94411b2d7051e82bc9c...            13.0
# 104773  2dc23b59ca957082adb9d31f4569e4eb0b4a47837c5191...            16.0
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 1                   2017-03-20                          F
# 8                   2017-04-29                          F
# 15                  2008-03-03                          M
# 26                  2007-04-24                          F
# 34                  2008-10-24                          F
# ...                        ...                        ...
# 104758              2014-04-04                          M
# 104765              2015-03-06                          F
# 104768              2010-07-14                          F
# 104772              2008-08-07                          F
# 104773              2005-06-16                          M
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 1                           3.0                  PARDA
# 8                           3.0                  PARDA
# 15                          3.0                  PARDA
# 26                          3.0                  PARDA
# 34                          4.0                AMARELA
# ...                         ...                    ...
# 104758                      3.0                  PARDA
# 104765                      3.0                  PARDA
# 104768                      3.0                  PARDA
# 104772                      3.0                  PARDA
# 104773                      1.0                 BRANCA
#
#         paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 1                                120030.0                      10.0
# 8                                120070.0                      10.0
# 15                               120040.0                      10.0
# 26                               120040.0                      10.0
# 34                               120070.0                      10.0
# ...                                   ...                       ...
# 104758                           120020.0                      10.0
# 104765                           120040.0                      10.0
# 104768                           120040.0                      10.0
# 104772                           120040.0                      10.0
# 104773                           120039.0                      10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 1                              FEIJO  ...                     NaN
# 8                             XAPURI  ...                     NaN
# 15                        RIO BRANCO  ...                     2.0
# 26                        RIO BRANCO  ...                     2.0
# 34                            XAPURI  ...                     2.0
# ...                              ...  ...                     ...
# 104758               CRUZEIRO DO SUL  ...                     NaN
# 104765                    RIO BRANCO  ...                     2.0
# 104768                    RIO BRANCO  ...                     NaN
# 104772                    RIO BRANCO  ...                     2.0
# 104773                  PORTO WALTER  ...                     2.0
#
#        vacina_categoria_nome  vacina_lote  vacina_fabricante_nome  \
# 1                        NaN       FW4423     PFIZER - PEDIÁTRICA
# 8                        NaN       FR8392  Pendente Identificação
# 15              Faixa Etária       FH4750                  PFIZER
# 26              Faixa Etária       FA9096                  PFIZER
# 34              Faixa Etária       230165                BUTANTAN
# ...                      ...          ...                     ...
# 104758                   NaN       FP0362     PFIZER - PEDIÁTRICA
# 104765          Faixa Etária       230165                BUTANTAN
# 104768                   NaN       FP7498                  PFIZER
# 104772          Faixa Etária       FF8848                  PFIZER
# 104773          Faixa Etária       FD7210                  PFIZER
#
#         vacina_fabricante_referencia vacina_dataAplicacao  \
# 1                              28290           2022-12-13
# 8                 Organization/28290           2022-05-30
# 15                Organization/28290           2021-11-29
# 26       Organization/00394544000851           2021-08-10
# 34                               152           2023-12-04
# ...                              ...                  ...
# 104758                         28290           2022-08-02
# 104765                           152           2024-01-10
# 104768                         28290           2022-08-03
# 104772   Organization/00394544000851           2021-10-15
# 104773   Organization/00394544000851           2021-08-28
#
#        vacina_descricao_dose  vacina_codigo  \
# 1                    2ª Dose             99
# 8                    1ª Dose             99
# 15                   2ª Dose             87
# 26                   1ª Dose             87
# 34                     Única             33
# ...                      ...            ...
# 104758               1ª Dose             99
# 104765                 Única             33
# 104768               1ª Dose             87
# 104772               2ª Dose             87
# 104773               1ª Dose             87
#
#                                    vacina_nome sistema_origem
# 1       COVID-19 PFIZER - COMIRNATY PEDIÁTRICA       Novo PNI
# 8       COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 15                 COVID-19 PFIZER - COMIRNATY       Novo PNI
# 26                 COVID-19 PFIZER - COMIRNATY       Novo PNI
# 34                                        INF3       Novo PNI
# ...                                        ...            ...
# 104758  COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 104765                                    INF3       Novo PNI
# 104768             COVID-19 PFIZER - COMIRNATY       Novo PNI
# 104772             COVID-19 PFIZER - COMIRNATY       Novo PNI
# 104773             COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [20000 rows x 32 columns]

# %%
# 2)Criar uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()
colunas = df_menores_18.columns.tolist()
colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3)Nesse DataFrame, fazer uma contagem do campo vacina_categoria_nome
contagem_categoria = df_menores_18['vacina_categoria_nome'].value_counts()
contagem_categoria
# Out:
# vacina_categoria_nome
# Faixa Etária                                      42156
# Povos Indígenas                                    3769
# Outros                                             3733
# Povos e Comunidades Tradicionais                    673
# Trabalhadores de Saúde                              237
# Comorbidades                                         49
# População Privada de Liberdade                       47
# Gestantes                                            38
# Pessoas com Deficiência                               7
# Puérperas                                             7
# Pessoas Institucionalizadas                           2
# Pessoas de 60 anos ou mais institucionalizadas        1
# Name: count, dtype: int64

# %%
# 4)A partir da lista de colunas, escolher somente aquelas que são referentes ao estabelecimento, fazer uma lista com esses valores
colunas_estabelecimento = [coluna for coluna in colunas if 'estabelecimento' in coluna]
colunas_estabelecimento
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5)Usando o método .loc, selecionar somente essas variáveis
dados_estabelecimento = df_menores_18.loc[:, colunas_estabelecimento]
dados_estabelecimento
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 1                      924490            PREFEITURA MUNICIPAL DE FEIJO
# 8                     2001225           PREFEITURA MUNICIPAL DE XAPURI
# 15                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 26                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 34                    2001217           PREFEITURA MUNICIPAL DE XAPURI
# ...                       ...                                      ...
# 375245                2001934           PREFEITURA MUNICIPAL DE XAPURI
# 375246                2002132        PREFEITURA MUN DE MAL THAUMATURGO
# 375255                2000342  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 375258                2000598  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 375261                3810771         PREFEITURA MUNICIPAL DE TARAUACA
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 1                                 120030                          FEIJO
# 8                                 120070                         XAPURI
# 15                                120040                     RIO BRANCO
# 26                                120040                     RIO BRANCO
# 34                                120070                         XAPURI
# ...                                  ...                            ...
# 375245                            120070                         XAPURI
# 375246                            120035           MARECHAL THAUMATURGO
# 375255                            120020                CRUZEIRO DO SUL
# 375258                            120020                CRUZEIRO DO SUL
# 375261                            120060                       TARAUACA
#
#        estabelecimento_uf
# 1                      AC
# 8                      AC
# 15                     AC
# 26                     AC
# 34                     AC
# ...                   ...
# 375245                 AC
# 375246                 AC
# 375255                 AC
# 375258                 AC
# 375261                 AC
#
# [70702 rows x 5 columns]

# %%
# 6) Aplicar o método .drop_duplicates e criar uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento
estabelecimentos_unicos = dados_estabelecimento.drop_duplicates()

# Imprimir resultados
print("Contagem de vacinas por categoria:\n")
print(contagem_categoria.to_string())

print("\nDados dos estabelecimentos únicos:\n")
print(estabelecimentos_unicos.to_string(index=False))
# Out:
# Contagem de vacinas por categoria:
#
# vacina_categoria_nome
# Faixa Etária                                      42156
# Povos Indígenas                                    3769
# Outros                                             3733
# Povos e Comunidades Tradicionais                    673
# Trabalhadores de Saúde                              237
# Comorbidades                                         49
# População Privada de Liberdade                       47
# Gestantes                                            38
# Pessoas com Deficiência                               7
# Puérperas                                             7
# Pessoas Institucionalizadas                           2
# Pessoas de 60 anos ou mais institucionalizadas        1
#
# Dados dos estabelecimentos únicos:
#
#  estabelecimento_valor                                  estabelecimento_razaoSocial  estabelecimento_municipio_codigo estabelecimento_municipio_nome estabelecimento_uf
#                 924490                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                2001225                               PREFEITURA MUNICIPAL DE XAPURI                            120070                         XAPURI                 AC
#                6917291                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001217                               PREFEITURA MUNICIPAL DE XAPURI                            120070                         XAPURI                 AC
#                3006166                           PREFEITURA MUNICIPAL DE ACRELANDIA                            120001                     ACRELANDIA                 AC
#                6992811                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                2000660                     PREFEITURA MUNICIPAL DE SENADOR GUIOMARD                            120045               SENADOR GUIOMARD                 AC
#                2000261                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                3810771                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                2001772                  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS                            120043            SANTA ROSA DO PURUS                 AC
#                 468363                                                REDE DE FRIOS                            120033                    MANCIO LIMA                 AC
#                2002922                                SECRETARIA MUNICIPAL DE SAUDE                            120038              PLACIDO DE CASTRO                 AC
#                2003198                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000628                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000164                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                5981891                      PREFEITURA MUNICIIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                6934013                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                2001934                               PREFEITURA MUNICIPAL DE XAPURI                            120070                         XAPURI                 AC
#                7915241                                PREFEITURA MUNICIPAL DE SAUDE                            120020                CRUZEIRO DO SUL                 AC
#                6748759          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA                            120030                          FEIJO                 AC
#                2000954                        PREFEITURA MUNICIPAL DE MANUEL URBANO                            120034                  MANOEL URBANO                 AC
#                2001128                           PREFEITURA MUNICIPAL DE PORTO ACRE                            120080                     PORTO ACRE                 AC
#                2000237                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                6568629                          PREFEITURA MUNICIPAL DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                5354072                               PREFEITURA MUNICIPAL DE JORDAO                            120032                         JORDAO                 AC
#                3541592                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                2002272                          PREFEITURA MUNICIPAL DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                6289312          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO PURUS                            120043            SANTA ROSA DO PURUS                 AC
#                2002132                            PREFEITURA MUN DE MAL THAUMATURGO                            120035           MARECHAL THAUMATURGO                 AC
#                5710111                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2001748                         PREFEITURA MUNICIPAL DE PORTO WALTER                            120039                   PORTO WALTER                 AC
#                2002876                                 SECRETARIA MUNCIPAL DE SAUDE                            120013                         BUJARI                 AC
#                2001039                             PREFEITURA MUNICIPAL DE CAPIXABA                            120017                       CAPIXABA                 AC
#                2001314                       PREFEITURA MUNICIPAL DE EPITACIOLANDIA                            120025                 EPITACIOLANDIA                 AC
#                2001101                           PREFEITURA MUNICIPAL DE PORTO ACRE                            120080                     PORTO ACRE                 AC
#                2002825                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                2000156                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                2000318                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                7232489                                PREFEITURA MUNICIPAL DE SAUDE                            120020                CRUZEIRO DO SUL                 AC
#                2000555                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000016                      PREFEITURA MUNICIPAL DE RODRIGUES ALVES                            120042                RODRIGUES ALVES                 AC
#                6917682          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA                            120020                CRUZEIRO DO SUL                 AC
#                6764533                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                6159087                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                6430201              DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA                            120032                         JORDAO                 AC
#                2003066                         PREFEITURA MUNICIPAL DE ASSIS BRASIL                            120005                   ASSIS BRASIL                 AC
#                2002914                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2001349                            PREFEITURA MUNICIPAL DE BRASILEIA                            120010                      BRASILEIA                 AC
#                2000202                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                3007367                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                6612385                                        POLO BASE DE TARAUACA                            120060                       TARAUACA                 AC
#                3959082                                SECRETARIA DE ESTADO DE SAUDE                            120020                CRUZEIRO DO SUL                 AC
#                2000598                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                3797554                         PREFEITURA MUNICIPAL DE ASSIS BRASIL                            120005                   ASSIS BRASIL                 AC
#                9648968 DISTRITO SANITARIO ESPECIAL DE SAUDE INDIGENA ALTO RIO PURUS                            120034                  MANOEL URBANO                 AC
#                2000067                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                2000326                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000059                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                2000040                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                6955525          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA                            120033                    MANCIO LIMA                 AC
#                7168748                          PREFEITURA MUNICIPAL DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                7110065                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3449432                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                6697151                                          MINISTERIO DA SAUDE                            120050                 SENA MADUREIRA                 AC
#                7797494                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                7014147                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                2000482                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000547                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                3544915                                PREFEITURA MUNICIPAL DE FEIJO                            120030                          FEIJO                 AC
#                6428940                         PREFEITURA MUNICIPAL DE ASSIS BRASIL                            120005                   ASSIS BRASIL                 AC
#                2000571                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2002299                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                3331946                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000407                               PREFEITURA MUNICIPAL DE XAPURI                            120070                         XAPURI                 AC
#                2002566                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                2000873                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                7247435                                PREFEITURA MUNICIPAL DE SAUDE                            120020                CRUZEIRO DO SUL                 AC
#                3323293                           PREFEITURA MUNICIPAL DE PORTO ACRE                            120080                     PORTO ACRE                 AC
#                2000962                        PREFEITURA MUNICIPAL DE MANUEL URBANO                            120034                  MANOEL URBANO                 AC
#                2306379                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3015521                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                7959087                                    MUNICIPIO DE PORTO WALTER                            120039                   PORTO WALTER                 AC
#                2002302                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                7375913                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000938                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                6308740          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA                            120039                   PORTO WALTER                 AC
#                7139454                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                7625855          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA                            120035           MARECHAL THAUMATURGO                 AC
#                2000342                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                7617852                                 PREFEITURA DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                2000334                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                 837822                                     MUNICIPIO DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                9014896                            MUNICIPIO DE MARECHAL THAUMATURGO                            120035           MARECHAL THAUMATURGO                 AC
#                3015556                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000520                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2003171                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                6119697                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3015548                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001896                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                7818092                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                7560583                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                6612385                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                2000504                           PREFEITURA MUNICIPAL DE PORTO ACRE                            120080                     PORTO ACRE                 AC
#                9542566                                    PREFEITURA DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                2000601                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000903                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                7147422                                SECRETARIA DE ESTADO DE SAUDE                            120040                     RIO BRANCO                 AC
#                3462366                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                2000105                          PREFEITURA MUNICIPAL DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                9948759                                      PREFEITURA DE BRASILEIA                            120010                      BRASILEIA                 AC
#                7120680                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2002221                             PREFEITURA MUNICIPAL MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                2000369                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2003015                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                7560141                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000741                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001470                            PREFEITURA MUNICIPAL DE BRASILEIA                            120010                      BRASILEIA                 AC
#                2000091                          PREFEITURA MUNICIPAL DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                9463208                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001306                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000881                       PREFEITURA MUNICIPAL DE SENA MADUREIRA                            120050                 SENA MADUREIRA                 AC
#                2000415                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000490                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                6270638                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                3015483                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                5371643                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                3323307                           PREFEITURA MUNICIPAL DE PORTO ACRE                            120080                     PORTO ACRE                 AC
#                7058322                            PREFEITURA MUNICIPAL DE BRASILEIA                            120010                      BRASILEIA                 AC
#                7036302          DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA                            120020                CRUZEIRO DO SUL                 AC
#                7436440                         PREFEITURA MUNICIPAL DE ASSIS BRASIL                            120005                   ASSIS BRASIL                 AC
#                5336171                        SECRETARIA DE ESTADO DE SAUDE DO ACRE                            120020                CRUZEIRO DO SUL                 AC
#                2001853                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3752259                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                7561113                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2000113                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                2001462                            PREFEITURA MUNICIPAL DE BRASILEIA                            120010                      BRASILEIA                 AC
#                7799632                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000806                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001454                            PREFEITURA MUNICIPAL DE BRASILEIA                            120010                      BRASILEIA                 AC
#                2000075                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000458                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2002701                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001845                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3015513                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                9908382                                          USF AEROPORTO VELHO                            120040                     RIO BRANCO                 AC
#                2003155                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3901009                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                3900975                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                3331806                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                7560133                      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                            120020                CRUZEIRO DO SUL                 AC
#                2001829                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                5174678                             PREFEITURA MUNICIPAL DE TARAUACA                            120060                       TARAUACA                 AC
#                3042553                            PREFEITURA MUNICIPAL DE BRASILEIA                            120010                      BRASILEIA                 AC
#                2001713                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001012                        SECRETARIA DE ESTADO DE SAUDE DO ACRE                            120040                     RIO BRANCO                 AC
#                3331776                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2001837                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                7565534                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                3331784                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                 899593                                     MUNICIPIO DE MANCIO LIMA                            120033                    MANCIO LIMA                 AC
#                2002884                               PREFEITURA MUNICIPAL DE BUJARI                            120013                         BUJARI                 AC
#                3331911                           PREFEITURA MUNICIPAL DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2000296                                SECRETARIA DE ESTADO DE SAUDE                            120020                CRUZEIRO DO SUL                 AC
#                2001357                   SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA                            120010                      BRASILEIA                 AC
#                9957650                                SECRETARIA DE ESTADO DE SAUDE                            120020                CRUZEIRO DO SUL                 AC
#                2003031                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                2003287                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
#                 755605                                           USF BARRO VERMELHO                            120040                     RIO BRANCO                 AC
#                9296042                     PREFEITURA MUNICIPAL DE SENADOR GUIOMARD                            120045               SENADOR GUIOMARD                 AC
#                9830464                                       MUNICIPIO DE BRASILEIA                            120010                      BRASILEIA                 AC
#                 115606                                          K M OLIVEIRA EIRELI                            120020                CRUZEIRO DO SUL                 AC
#                2003058                                      MUNICIPIO DE RIO BRANCO                            120040                     RIO BRANCO                 AC
